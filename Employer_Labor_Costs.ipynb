# %%
import pandas as pd
import numpy as np

# %%
#check path is correct
import os
working_directory = os.getcwd()
print(working_directory)
# Out:
# /Users/ITO/Google Tech Mentorship Projects/P1 - Labor market forecasting

# %%
path = working_directory + '/Employee_Payroll.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Fiscal Year  Fiscal Quarter Fiscal Period First Name Last Name Middle Init  \
# 0         2016               1        2016Q1     AMRITH     AAKRE           K
# 1         2016               2        2016Q2     AMRITH     AAKRE           K
# 2         2016               3        2016Q3     AMRITH     AAKRE           K
# 3         2016               4        2016Q4     AMRITH     AAKRE           K
# 4         2017               1        2017Q1     AMRITH     AAKRE           K
#
#              Bureau  Office      Office Name  Job Code  \
# 0  State's Attorney  1250.0  STATES ATTORNEY      1172
# 1  State's Attorney  1250.0  STATES ATTORNEY      1172
# 2  State's Attorney  1250.0  STATES ATTORNEY      1172
# 3  State's Attorney  1250.0  STATES ATTORNEY      1172
# 4  State's Attorney  1250.0  STATES ATTORNEY      1172
#
#                     Job Title  Base Pay  Position ID  \
# 0  Assistant State's Attorney  20088.00      9510200
# 1  Assistant State's Attorney  23436.00      9510200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234299 entries, 0 to 234298
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Fiscal Year          234299 non-null  int64
#  1   Fiscal Quarter       234299 non-null  int64
#  2   Fiscal Period        234299 non-null  object
#  3   First Name           234299 non-null  object
#  4   Last Name            234299 non-null  object
#  5   Middle Init          140887 non-null  object
#  6   Bureau               234299 non-null  object
#  7   Office               231115 non-null  float64
#  8   Office Name          231115 non-null  object
#  9   Job Code             234299 non-null  int64
#  10  Job Title            234299 non-null  object
#  11  Base Pay             234295 non-null  float64
#  12  Position ID          234299 non-null  int64
#  13  Employee Identifier  234299 non-null  object
#  14  Original Hire Date   234299 non-null  object
# ...

# %%
df.describe()
# Out:
#          Fiscal Year  Fiscal Quarter         Office       Job Code  \
# count  234299.000000   234299.000000  231115.000000  234299.000000
# mean     2016.829005        2.257381    2268.636778    2236.125622
# std         0.768902        1.094660    1611.800171    1926.398577
# min      2016.000000        1.000000    1002.000000       1.000000
# 25%      2016.000000        1.000000    1239.000000    1172.000000
# 50%      2017.000000        2.000000    1280.000000    1360.000000
# 75%      2017.000000        3.000000    4890.000000    2381.000000
# max      2018.000000        4.000000    4898.000000    8097.000000
#
#             Base Pay   Position ID
# count  234295.000000  2.342990e+05
# mean    16795.426916  7.309608e+06
# std     10716.170305  3.745045e+06
# min    -19562.150000  4.700000e+01
# 25%     11490.950000  1.803613e+06
# 50%     15826.420000  9.508001e+06
# 75%     20396.430000  9.516444e+06
# max    242576.340000  9.935320e+06

# %%
df.tail()
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#        Middle Init                          Bureau  Office  \
# 234294          E.                 STATES ATTORNEY  1250.0
# 234295           J        DEPT. OF FACILITIES/MGMT  1200.0
# 234296           R           ADULT PROBATION DEPT.  1280.0
# 234297         NaN  AMBULATORY COMMUNITY HLTH NTWK  4893.0
# 234298         NaN  JUVENILE TEMPORARY DETENT.CNTR  1440.0
#
#                            Office Name  Job Code  \
# 234294                 STATES ATTORNEY      1172
# 234295        DEPT. OF FACILITIES/MGMT      2452
# ...

# %%
df["Bureau"].value_counts()
# Out:
# Bureau of Health              53903
# Sheriff                       51951
# Chief Judge                   24322
# Clerk of Circuit Ct.          13089
# State's Attorney              11105
#                               ...
# SEVENTEENTH DISTRICT              8
# FIFTEENTH DISTRICT                8
# ELEVENTH DISTRICT                 6
# ZONING BOARD OF APPEALS           6
# DEPT OF ENVIRONMENTAL CTRL        2
# Name: Bureau, Length: 111, dtype: int64
